# %% [markdown]
# #BiLSTM
#
# Sudah sampai evaluasi 1, 3, 7 RMSE dan CC
#
# Cara Running Load Model
# 1. Import
# 2. Read Data
# 3. Split Data
# 4. Normalisasi pakai Standart Scaler
# 5. Pisah tanggal untuk forecast day 1, 3, 7.
# 6. Membuat fungsi sliding window
# 7. Mengaktifkan fungsi ke X, y
# 8. Membuat fungsi CC dan Load Model
# 9. Evaluasi pada Day 1, 3, 7 dengan RMSE dan CC
# 10. Membuat Dataframe dari Predicted value (y_pred)
# 11. Visualisasi Day 1, 3, 7

# %%
#Step 1
import numpy as np
import joblib
import pandas as pd
import datetime
import tensorflow as tf
import os
import random
import timeit
import seaborn as sns
import datetime
import matplotlib.pyplot as plt

import tensorflow_probability as tfp
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, Bidirectional, Dropout
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
#Step 2
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_excel('/content/drive/MyDrive/databeban_merged.xlsx')
# Out:
# Mounted at /content/drive

# %%
df = df.set_index('datetime')
df.index = pd.to_datetime(df.index)

# %%
df
# Out:
#                        load
# datetime
# 2018-01-01 00:30:00  554.80
# 2018-01-01 01:00:00  545.80
# 2018-01-01 01:30:00  534.70
# 2018-01-01 02:00:00  521.50
# 2018-01-01 02:30:00  496.50
# ...                     ...
# 2019-12-31 22:00:00  807.81
# 2019-12-31 22:30:00  788.11
# 2019-12-31 23:00:00  773.05
# 2019-12-31 23:30:00  753.55
# 2020-01-01 00:00:00  726.00
#
# [35040 rows x 1 columns]

# %%
#Step 3
# Split the data into training, validation, and test sets
n = len(df)
n_train = int(0.8 * n)
n_val = int(0.1 * n)
n_test = n - n_train - n_val

train_data = df[:n_train].drop(columns=['datetime']).values
train_date = df[:n_train].drop(columns=['load'])

val_data   = df[n_train:n_train+n_val].drop(columns=['datetime']).values
val_date   = df[n_train:n_train+n_val].drop(columns=['load'])

test_data  = df[-n_test:].drop(columns=['datetime']).values
test_date  = df[-n_test:].drop(columns=['load'])

# %%
test_date
# Out:
#                  datetime
# 31536 2019-10-20 00:30:00
# 31537 2019-10-20 01:00:00
# 31538 2019-10-20 01:30:00
# 31539 2019-10-20 02:00:00
# 31540 2019-10-20 02:30:00
# ...                   ...
# 35035 2019-12-31 22:00:00
# 35036 2019-12-31 22:30:00
# 35037 2019-12-31 23:00:00
# 35038 2019-12-31 23:30:00
# 35039 2020-01-01 00:00:00
#
# [3504 rows x 1 columns]

# %%
print('Train Set      : ',len(train_data))
print('Validation Set : ',len(val_data))
print('Test Set       : ',len(test_data))
# Out:
# Train Set      :  28032
# Validation Set :  3504
# Test Set       :  3504

# %%
#Step 4
# Normalize the data using StandardScaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_data = scaler.fit_transform(train_data)
val_data   = scaler.transform(val_data)
test_data  = scaler.transform(test_data)

# %%
#Step 5
#Take day for predict from data test, 48 = 1 day

one_day_date = test_date.head(48)
one_day_data = test_data[:48]

three_day_date = test_date.head(144)
three_day_data = test_data[:144]

seven_day_date = test_date.head(336)
seven_day_data = test_data[:336]

# %%
#Step 6 
#Create a windowed dataset for training
window_size = 48 # (1 weeks) use 48 from interval one day of data for each window
def create_window_dataset(data, window_size):
    X = []
    y = []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i])
        y.append(data[i])
    return np.array(X), np.array(y)

# %%
train_data
# Out:
# array([[-1.08440691],
#        [-1.17490414],
#        [-1.2865174 ],
#        ...,
#        [-0.52875391],
#        [-0.83171853],
#        [-1.01814283]])

# %%
original_data = scaler.inverse_transform(train_data)
original_data
# Out:
# array([[554.8 ],
#        [545.8 ],
#        [534.7 ],
#        ...,
#        [610.06],
#        [579.93],
#        [561.39]])

# %%
#Step 7
X_train, y_train = create_window_dataset(train_data, window_size)
X_val, y_val     = create_window_dataset(val_data, window_size)
X_test, y_test   = create_window_dataset(test_data, window_size)

# %%
#Step 8
def cc(y_true, y_pred):
    """
    Compute the correlation coefficient between y_true and y_pred.
    """
    # Compute the covariance matrix
    cov = tfp.stats.covariance(y_true, y_pred, sample_axis=0)

    # Compute the standard deviation of y_true and y_pred
    std_true = K.std(y_true)
    std_pred = K.std(y_pred)

    # Compute the correlation coefficient
    return cov / (std_true * std_pred)

# %%
#Step 8
from keras.models import load_model
import pickle

# Load the trained model
model= load_model('/content/drive/MyDrive/Model/BiLSTM_Model_Final.h5', custom_objects={"cc": cc})

# Load the history object
with open('/content/drive/MyDrive/Model/BiLSTM_history_Final.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
input_shape = (window_size, 1)

model = Sequential([
    Bidirectional(LSTM(32, return_sequences=True)),
    Bidirectional(LSTM(32)),

    Dense(32, activation='relu'),
    Dense(1)
])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001)
model.compile(optimizer= optimizer, 
              loss=tf.keras.losses.Huber(), 
              metrics= [RootMeanSquaredError(), cc])

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', 
                               patience=5, verbose=1,
                               mode='min', 
                               restore_best_weights=True)

# %%
history = model.fit(
    X_train, y_train, 
    epochs=50, 
    batch_size=16, 
    validation_data=(X_val, y_val), 
    callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 1749/1749 [==============================] - 32s 14ms/step - loss: 0.4086 - root_mean_squared_error: 0.9461 - cc: 0.7797 - val_loss: 0.3845 - val_root_mean_squared_error: 0.9014 - val_cc: 0.8148
# Epoch 2/50
# 1749/1749 [==============================] - 25s 14ms/step - loss: 0.3470 - root_mean_squared_error: 0.8624 - cc: 0.9269 - val_loss: 0.3234 - val_root_mean_squared_error: 0.8185 - val_cc: 0.8602
# Epoch 3/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.2908 - root_mean_squared_error: 0.7823 - cc: 0.9382 - val_loss: 0.2683 - val_root_mean_squared_error: 0.7403 - val_cc: 0.8731
# Epoch 4/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.2403 - root_mean_squared_error: 0.7063 - cc: 0.9386 - val_loss: 0.2178 - val_root_mean_squared_error: 0.6639 - val_cc: 0.8763
# Epoch 5/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.1941 - root_mean_squared_error: 0.6319 - cc: 0.9380 - val_loss: 0.1717 - val_root_mean_squared_error: 0.5880 - val_cc: 0.8775
# Epoch 6/50
# 1749/1749 [==============================] - 25s 14ms/step - loss: 0.1541 - root_mean_squared_error: 0.5618 - cc: 0.9363 - val_loss: 0.1332 - val_root_mean_squared_error: 0.5171 - val_cc: 0.8786
# Epoch 7/50
# 1749/1749 [==============================] - 22s 13ms/step - loss: 0.1222 - root_mean_squared_error: 0.5001 - cc: 0.9368 - val_loss: 0.1035 - val_root_mean_squared_error: 0.4553 - val_cc: 0.8794
# Epoch 8/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0987 - root_mean_squared_error: 0.4500 - cc: 0.9364 - val_loss: 0.0821 - val_root_mean_squared_error: 0.4053 - val_cc: 0.8804
# Epoch 9/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0825 - root_mean_squared_error: 0.4120 - cc: 0.9385 - val_loss: 0.0676 - val_root_mean_squared_error: 0.3676 - val_cc: 0.8814
# Epoch 10/50
# 1749/1749 [==============================] - 24s 14ms/step - loss: 0.0719 - root_mean_squared_error: 0.3851 - cc: 0.9391 - val_loss: 0.0581 - val_root_mean_squared_error: 0.3408 - val_cc: 0.8825
# Epoch 11/50
# 1749/1749 [==============================] - 22s 13ms/step - loss: 0.0650 - root_mean_squared_error: 0.3668 - cc: 0.9399 - val_loss: 0.0520 - val_root_mean_squared_error: 0.3225 - val_cc: 0.8837
# Epoch 12/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0606 - root_mean_squared_error: 0.3544 - cc: 0.9403 - val_loss: 0.0481 - val_root_mean_squared_error: 0.3101 - val_cc: 0.8849
# Epoch 13/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0576 - root_mean_squared_error: 0.3459 - cc: 0.9418 - val_loss: 0.0455 - val_root_mean_squared_error: 0.3016 - val_cc: 0.8862
# Epoch 14/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0555 - root_mean_squared_error: 0.3398 - cc: 0.9426 - val_loss: 0.0437 - val_root_mean_squared_error: 0.2957 - val_cc: 0.8875
# Epoch 15/50
# 1749/1749 [==============================] - 24s 14ms/step - loss: 0.0540 - root_mean_squared_error: 0.3352 - cc: 0.9440 - val_loss: 0.0424 - val_root_mean_squared_error: 0.2913 - val_cc: 0.8887
# Epoch 16/50
# 1749/1749 [==============================] - 24s 14ms/step - loss: 0.0528 - root_mean_squared_error: 0.3315 - cc: 0.9448 - val_loss: 0.0414 - val_root_mean_squared_error: 0.2879 - val_cc: 0.8898
# Epoch 17/50
# 1749/1749 [==============================] - 24s 14ms/step - loss: 0.0518 - root_mean_squared_error: 0.3285 - cc: 0.9456 - val_loss: 0.0406 - val_root_mean_squared_error: 0.2851 - val_cc: 0.8911
# Epoch 18/50
# 1749/1749 [==============================] - 22s 13ms/step - loss: 0.0509 - root_mean_squared_error: 0.3258 - cc: 0.9469 - val_loss: 0.0400 - val_root_mean_squared_error: 0.2827 - val_cc: 0.8922
# Epoch 19/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0502 - root_mean_squared_error: 0.3235 - cc: 0.9475 - val_loss: 0.0394 - val_root_mean_squared_error: 0.2806 - val_cc: 0.8932
# Epoch 20/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0495 - root_mean_squared_error: 0.3215 - cc: 0.9483 - val_loss: 0.0389 - val_root_mean_squared_error: 0.2788 - val_cc: 0.8942
# Epoch 21/50
# 1749/1749 [==============================] - 22s 13ms/step - loss: 0.0489 - root_mean_squared_error: 0.3196 - cc: 0.9488 - val_loss: 0.0384 - val_root_mean_squared_error: 0.2771 - val_cc: 0.8951
# Epoch 22/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0484 - root_mean_squared_error: 0.3179 - cc: 0.9494 - val_loss: 0.0380 - val_root_mean_squared_error: 0.2756 - val_cc: 0.8960
# Epoch 23/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0479 - root_mean_squared_error: 0.3164 - cc: 0.9494 - val_loss: 0.0376 - val_root_mean_squared_error: 0.2742 - val_cc: 0.8969
# Epoch 24/50
# 1749/1749 [==============================] - 22s 13ms/step - loss: 0.0474 - root_mean_squared_error: 0.3149 - cc: 0.9496 - val_loss: 0.0372 - val_root_mean_squared_error: 0.2729 - val_cc: 0.8977
# Epoch 25/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0470 - root_mean_squared_error: 0.3136 - cc: 0.9509 - val_loss: 0.0369 - val_root_mean_squared_error: 0.2716 - val_cc: 0.8985
# Epoch 26/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0466 - root_mean_squared_error: 0.3123 - cc: 0.9514 - val_loss: 0.0366 - val_root_mean_squared_error: 0.2705 - val_cc: 0.8992
# Epoch 27/50
# 1749/1749 [==============================] - 22s 12ms/step - loss: 0.0462 - root_mean_squared_error: 0.3112 - cc: 0.9516 - val_loss: 0.0363 - val_root_mean_squared_error: 0.2694 - val_cc: 0.8999
# Epoch 28/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0459 - root_mean_squared_error: 0.3101 - cc: 0.9520 - val_loss: 0.0360 - val_root_mean_squared_error: 0.2684 - val_cc: 0.9006
# Epoch 29/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0456 - root_mean_squared_error: 0.3090 - cc: 0.9522 - val_loss: 0.0357 - val_root_mean_squared_error: 0.2674 - val_cc: 0.9013
# Epoch 30/50
# 1749/1749 [==============================] - 22s 13ms/step - loss: 0.0453 - root_mean_squared_error: 0.3080 - cc: 0.9531 - val_loss: 0.0355 - val_root_mean_squared_error: 0.2665 - val_cc: 0.9019
# Epoch 31/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0449 - root_mean_squared_error: 0.3070 - cc: 0.9529 - val_loss: 0.0352 - val_root_mean_squared_error: 0.2655 - val_cc: 0.9025
# Epoch 32/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0446 - root_mean_squared_error: 0.3060 - cc: 0.9536 - val_loss: 0.0350 - val_root_mean_squared_error: 0.2646 - val_cc: 0.9030
# Epoch 33/50
# 1749/1749 [==============================] - 22s 13ms/step - loss: 0.0444 - root_mean_squared_error: 0.3050 - cc: 0.9534 - val_loss: 0.0348 - val_root_mean_squared_error: 0.2637 - val_cc: 0.9036
# Epoch 34/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0441 - root_mean_squared_error: 0.3041 - cc: 0.9540 - val_loss: 0.0345 - val_root_mean_squared_error: 0.2628 - val_cc: 0.9041
# Epoch 35/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0438 - root_mean_squared_error: 0.3032 - cc: 0.9541 - val_loss: 0.0343 - val_root_mean_squared_error: 0.2619 - val_cc: 0.9047
# Epoch 36/50
# 1749/1749 [==============================] - 22s 13ms/step - loss: 0.0435 - root_mean_squared_error: 0.3023 - cc: 0.9545 - val_loss: 0.0341 - val_root_mean_squared_error: 0.2610 - val_cc: 0.9052
# Epoch 37/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0433 - root_mean_squared_error: 0.3014 - cc: 0.9548 - val_loss: 0.0338 - val_root_mean_squared_error: 0.2601 - val_cc: 0.9057
# Epoch 38/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0430 - root_mean_squared_error: 0.3005 - cc: 0.9549 - val_loss: 0.0336 - val_root_mean_squared_error: 0.2592 - val_cc: 0.9062
# Epoch 39/50
# 1749/1749 [==============================] - 24s 13ms/step - loss: 0.0427 - root_mean_squared_error: 0.2996 - cc: 0.9550 - val_loss: 0.0334 - val_root_mean_squared_error: 0.2583 - val_cc: 0.9067
# Epoch 40/50
# 1749/1749 [==============================] - 22s 13ms/step - loss: 0.0425 - root_mean_squared_error: 0.2987 - cc: 0.9554 - val_loss: 0.0331 - val_root_mean_squared_error: 0.2574 - val_cc: 0.9073
# Epoch 41/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0422 - root_mean_squared_error: 0.2978 - cc: 0.9554 - val_loss: 0.0329 - val_root_mean_squared_error: 0.2565 - val_cc: 0.9077
# Epoch 42/50
# 1749/1749 [==============================] - 24s 14ms/step - loss: 0.0420 - root_mean_squared_error: 0.2970 - cc: 0.9561 - val_loss: 0.0327 - val_root_mean_squared_error: 0.2556 - val_cc: 0.9083
# Epoch 43/50
# 1749/1749 [==============================] - 22s 13ms/step - loss: 0.0417 - root_mean_squared_error: 0.2961 - cc: 0.9566 - val_loss: 0.0324 - val_root_mean_squared_error: 0.2547 - val_cc: 0.9088
# Epoch 44/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0415 - root_mean_squared_error: 0.2953 - cc: 0.9566 - val_loss: 0.0322 - val_root_mean_squared_error: 0.2538 - val_cc: 0.9093
# Epoch 45/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0412 - root_mean_squared_error: 0.2944 - cc: 0.9570 - val_loss: 0.0320 - val_root_mean_squared_error: 0.2529 - val_cc: 0.9098
# Epoch 46/50
# 1749/1749 [==============================] - 22s 13ms/step - loss: 0.0410 - root_mean_squared_error: 0.2936 - cc: 0.9577 - val_loss: 0.0317 - val_root_mean_squared_error: 0.2519 - val_cc: 0.9104
# Epoch 47/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0407 - root_mean_squared_error: 0.2928 - cc: 0.9573 - val_loss: 0.0315 - val_root_mean_squared_error: 0.2510 - val_cc: 0.9109
# Epoch 48/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0405 - root_mean_squared_error: 0.2920 - cc: 0.9577 - val_loss: 0.0313 - val_root_mean_squared_error: 0.2502 - val_cc: 0.9114
# Epoch 49/50
# 1749/1749 [==============================] - 22s 13ms/step - loss: 0.0403 - root_mean_squared_error: 0.2912 - cc: 0.9584 - val_loss: 0.0311 - val_root_mean_squared_error: 0.2493 - val_cc: 0.9119
# Epoch 50/50
# 1749/1749 [==============================] - 23s 13ms/step - loss: 0.0400 - root_mean_squared_error: 0.2904 - cc: 0.9581 - val_loss: 0.0308 - val_root_mean_squared_error: 0.2484 - val_cc: 0.9124

# %%
# Plot the training and validation metrics
plt.plot(history['loss'], label='Training loss')
plt.plot(history['val_loss'], label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
plt.plot(history['root_mean_squared_error'], label='Training RMSE')
plt.plot(history['val_root_mean_squared_error'], label='Validation RMSE')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
plt.plot(history['cc'], label='Training CC')
plt.plot(history['val_cc'], label='Validation CC')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_rmse, test_cc = model.evaluate(X_test, y_test)

# Make predictions on the test set
y_pred = model.predict(X_test)
# Out:
# 108/108 [==============================] - 3s 8ms/step - loss: 0.1261 - root_mean_squared_error: 0.5042 - cc: 0.9099
# 108/108 [==============================] - 3s 7ms/step

# %%
# Plot the predicted and true labels
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(y_test, label='True Labels')
plt.plot(y_pred, label='Predicted Labels')
plt.legend()
plt.show()

# %%
#Step 9
#Evaluate the model on the 1, 3, 7 Days to Forecast
X_one   = X_test[:48]
X_three = X_test[:144]
X_seven = X_test[:336]

y_one   = y_test[:48]
y_three = y_test[:144]
y_seven = y_test[:336]

print("1 Day to Forecast")
test_loss, test_rmse, test_cc = model.evaluate(X_one, y_one)
y_pred_one = model.predict(X_one)


print("3 Days to Forecast")
test_loss, test_rmse, test_cc = model.evaluate(X_three, y_three)
y_pred_three = model.predict(X_three)

print("7 Days to Forecast")
test_loss, test_rmse, test_cc = model.evaluate(X_seven, y_seven)
y_pred_seven = model.predict(X_seven)
# Out:
# 1 Day to Forecast
# 2/2 [==============================] - 5s 31ms/step - loss: 0.1069 - root_mean_squared_error: 0.4624 - cc: 0.9459
# 2/2 [==============================] - 2s 33ms/step
# 3 Days to Forecast
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0747 - root_mean_squared_error: 0.3866 - cc: 0.9415
# 5/5 [==============================] - 0s 37ms/step
# 7 Days to Forecast
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0658 - root_mean_squared_error: 0.3627 - cc: 0.9345
# 11/11 [==============================] - 0s 36ms/step

# %%
#Step 10
#Inverse from scaled data
inv_pred_one = scaler.inverse_transform(y_pred_one)
inv_one      = scaler.inverse_transform(y_one)

inv_pred_three = scaler.inverse_transform(y_pred_three)
inv_three      = scaler.inverse_transform(y_three)

inv_pred_seven = scaler.inverse_transform(y_pred_seven)
inv_seven      = scaler.inverse_transform(y_seven)

#Copy data date
viz_one   = one_day_date.copy()
viz_three = three_day_date.copy()
viz_seven = seven_day_date.copy()

#Join true and predicted data
viz_one['load_pred'] = inv_pred_one
viz_one['load_true'] = inv_one

viz_three['load_pred'] = inv_pred_three
viz_three['load_true'] = inv_three

viz_seven['load_pred'] = inv_pred_seven
viz_seven['load_true'] = inv_seven

# %%
#1 Day Forecasting

# Load dataset
viz_one = viz_one.set_index('datetime')

# Plot two columns in one chart
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(viz_one.index, viz_one['load_pred'], label='Predicted')
ax.plot(viz_one.index, viz_one['load_true'], label='True Label')

# Add labels and legend
ax.set_xlabel('Datetime')
ax.set_ylabel('Load Electricity')
ax.set_title('1 Day Forecasting')
ax.legend()

# Show plot
plt.show()

# %%
#3 Days Forecasting

# Load dataset
viz_three = viz_three.set_index('datetime')

# Plot two columns in one chart
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(viz_three.index, viz_three['load_pred'], label='Predicted')
ax.plot(viz_three.index, viz_three['load_true'], label='True Label')

# Add labels and legend
ax.set_xlabel('Datetime')
ax.set_ylabel('Load Electricity')
ax.set_title('3 Days Forecasting')
ax.legend()

# Show plot
plt.show()

# %%
#7 Days Forecasting

# Load dataset
viz_seven = viz_seven.set_index('datetime')

# Plot two columns in one chart
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(viz_seven.index, viz_seven['load_pred'], label='Predicted')
ax.plot(viz_seven.index, viz_seven['load_true'], label='True Label')

# Add labels and legend
ax.set_xlabel('Datetime')
ax.set_ylabel('Load Electricity')
ax.set_title('7 Days Forecasting')
ax.legend()

# Show plot
plt.show()

# %%
import pickle

# Save the trained model
model.save('/content/drive/MyDrive/Model/BiLSTM_Model_Final.h5')

# Save the history object
with open('/content/drive/MyDrive/Model/BiLSTM_history_Final.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
model_load.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (None, 128)              33792
#  nal)
#
#  dense_8 (Dense)             (None, 32)                4128
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 37,953
# Trainable params: 37,953
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
len(y_test)
# Out:
# 3432

# %% [markdown]
# #Use Model To Forecasting
#
# Load Library, Model, and Addition First

# %%
#1. Merge array data for base predict
x_data = np.vstack((X_train, X_val, X_test))
x_data
# Out:
# array([[[-1.08440691],
#         [-1.17490414],
#         [-1.2865174 ],
#         ...,
#         [-0.36847326],
#         [-0.64700363],
#         [-0.93558924]],
#
#        [[-1.17490414],
#         [-1.2865174 ],
#         [-1.41924667],
#         ...,
#         [-0.64700363],
#         [-0.93558924],
#         [-1.13870525]],
#
#        [[-1.2865174 ],
#         [-1.41924667],
#         [-1.67062787],
#         ...,
#         [-0.93558924],
#         [-1.13870525],
#         [-1.20808646]],
#
#        ...,
#
#        [[ 1.75489344],
#         [ 1.45223048],
#         [ 1.23443381],
#         ...,
#         [ 1.69928792],
#         [ 1.45967136],
#         [ 1.26158298]],
#
#        [[ 1.45223048],
#         [ 1.23443381],
#         [ 0.9075377 ],
#         ...,
#         [ 1.45967136],
#         [ 1.26158298],
#         [ 1.11015094]],
#
#        [[ 1.23443381],
#         [ 0.9075377 ],
#         [ 0.72754876],
#         ...,
#         [ 1.26158298],
#         [ 1.11015094],
#         [ 0.91407361]]])

# %%
len(val_data)
# Out:
# 3504

# %%
x_data.shape
# Out:
# (34896, 48, 1)

# %%
#2. test model prediction
import numpy as np

# Set the window size and n_steps
n_steps = 48*7 # 7 days

# Get the last window_size data points
start_index = len(x_data) - n_steps
n_step = x_data[start_index:]

# Make the predictions
y_pred = model.predict(n_step)

# Print the predicted values
print(y_pred)
# Out:
# 11/11 [==============================] - 9s 43ms/step
# [[ 0.95890063]
#  [ 0.82263774]
#  [ 0.68215233]
#  [ 0.5449197 ]
#  [ 0.42440116]
#  [ 0.32140833]
#  [ 0.24783622]
#  [ 0.20494439]
#  [ 0.19166969]
#  [ 0.21676129]
#  [ 0.2722003 ]
#  [ 0.35774773]
#  [ 0.46389484]
#  [ 0.5745772 ]
#  [ 0.68923956]
#  [ 0.8241418 ]
#  [ 0.92863995]
#  [ 1.0344634 ]
#  [ 1.1512821 ]
#  [ 1.2603636 ]
#  [ 1.354151  ]
#  [ 1.4211485 ]
#  [ 1.4705836 ]
#  [ 1.5040965 ]
#  [ 1.5296983 ]
#  [ 1.5494817 ]
#  [ 1.5648879 ]
#  [ 1.5767947 ]
#  [ 1.5852145 ]
#  [ 1.5909913 ]
#  [ 1.5931841 ]
#  [ 1.5934851 ]
#  [ 1.5928442 ]
#  [ 1.5925757 ]
#  [ 1.5925539 ]
#  [ 1.5925386 ]
#  [ 1.5948396 ]
#  [ 1.6025081 ]
#  [ 1.6073123 ]
#  [ 1.6050264 ]
#  [ 1.5971372 ]
#  [ 1.5799918 ]
#  [ 1.5552087 ]
#  [ 1.5235885 ]
#  [ 1.4830157 ]
#  [ 1.4122225 ]
#  [ 1.3277073 ]
#  [ 1.2000523 ]
#  [ 1.0567514 ]
#  [ 0.90960765]
#  [ 0.7685777 ]
#  [ 0.62021   ]
#  [ 0.4921    ]
#  [ 0.3849225 ]
#  [ 0.30286065]
#  [ 0.24845682]
#  [ 0.22270302]
#  [ 0.22830884]
#  [ 0.26111817]
#  [ 0.33353025]
#  [ 0.4298489 ]
#  [ 0.5612712 ]
#  [ 0.6944236 ]
#  [ 0.8426359 ]
#  [ 0.9728614 ]
#  [ 1.1236987 ]
#  [ 1.2603301 ]
#  [ 1.3702278 ]
#  [ 1.4479383 ]
#  [ 1.4984479 ]
#  [ 1.534731  ]
#  [ 1.5601304 ]
#  [ 1.5750661 ]
#  [ 1.5862747 ]
#  [ 1.5949234 ]
#  [ 1.6003822 ]
#  [ 1.603026  ]
#  [ 1.6026224 ]
#  [ 1.6033157 ]
#  [ 1.6035124 ]
#  [ 1.6030589 ]
#  [ 1.6021698 ]
#  [ 1.6017286 ]
#  [ 1.6014724 ]
#  [ 1.6049931 ]
#  [ 1.6079907 ]
#  [ 1.6101435 ]
#  [ 1.604644  ]
#  [ 1.591046  ]
#  [ 1.5692345 ]
#  [ 1.5428385 ]
#  [ 1.5087954 ]
#  [ 1.4568125 ]
#  [ 1.3796474 ]
#  [ 1.2757074 ]
#  [ 1.1485163 ]
#  [ 1.0213053 ]
#  [ 0.9070044 ]
#  [ 0.78849536]
#  [ 0.6847349 ]
#  [ 0.5883802 ]
#  [ 0.49873006]
#  [ 0.4408005 ]
#  [ 0.40465462]
#  [ 0.40364432]
#  [ 0.43405008]
#  [ 0.495655  ]
#  [ 0.5731672 ]
#  [ 0.66926664]
#  [ 0.77568054]
#  [ 0.861493  ]
#  [ 0.9496066 ]
#  [ 1.0676246 ]
#  [ 1.2000884 ]
#  [ 1.3295788 ]
#  [ 1.4339181 ]
#  [ 1.4996241 ]
#  [ 1.5410289 ]
#  [ 1.5686661 ]
#  [ 1.5880438 ]
#  [ 1.6033461 ]
#  [ 1.6107018 ]
#  [ 1.6133074 ]
#  [ 1.6127019 ]
#  [ 1.6064647 ]
#  [ 1.5988041 ]
#  [ 1.5865424 ]
#  [ 1.5728701 ]
#  [ 1.5601854 ]
#  [ 1.5507402 ]
#  [ 1.5443217 ]
#  [ 1.5411515 ]
#  [ 1.5395023 ]
#  [ 1.5430976 ]
#  [ 1.5547713 ]
#  [ 1.561627  ]
#  [ 1.5591571 ]
#  [ 1.5481035 ]
#  [ 1.5257405 ]
#  [ 1.4925108 ]
#  [ 1.4447397 ]
#  [ 1.3646498 ]
#  [ 1.263516  ]
#  [ 1.1220692 ]
#  [ 0.98330146]
#  [ 0.8230021 ]
#  [ 0.66613716]
#  [ 0.5079149 ]
#  [ 0.3766796 ]
#  [ 0.2756412 ]
#  [ 0.20004036]
#  [ 0.1530038 ]
#  [ 0.14042369]
#  [ 0.16115479]
#  [ 0.22058412]
#  [ 0.3097667 ]
#  [ 0.42835897]
#  [ 0.56330115]
#  [ 0.6797264 ]
#  [ 0.77678514]
#  [ 0.890988  ]
#  [ 1.0232171 ]
#  [ 1.156092  ]
#  [ 1.2781438 ]
#  [ 1.3735607 ]
#  [ 1.4385859 ]
#  [ 1.4739457 ]
#  [ 1.4960756 ]
#  [ 1.5070397 ]
#  [ 1.5135633 ]
#  [ 1.5162561 ]
#  [ 1.5146031 ]
#  [ 1.5148405 ]
#  [ 1.5111388 ]
#  [ 1.5057727 ]
#  [ 1.5008558 ]
#  [ 1.4971519 ]
#  [ 1.498077  ]
#  [ 1.5019696 ]
#  [ 1.508459  ]
#  [ 1.5169462 ]
#  [ 1.5283424 ]
#  [ 1.5412406 ]
#  [ 1.5451579 ]
#  [ 1.5385288 ]
#  [ 1.5225853 ]
#  [ 1.4974467 ]
#  [ 1.4585313 ]
#  [ 1.3914335 ]
#  [ 1.2929647 ]
#  [ 1.152408  ]
#  [ 1.0040874 ]
#  [ 0.84390235]
#  [ 0.670142  ]
#  [ 0.4954273 ]
#  [ 0.3365004 ]
#  [ 0.19410028]
#  [ 0.07939155]
#  [-0.00745071]
#  [-0.0609789 ]
#  [-0.07565022]
#  [-0.05006327]
#  [ 0.01283407]
#  [ 0.11139223]
#  [ 0.23012191]
#  [ 0.3652367 ]
#  [ 0.5293077 ]
#  [ 0.68896693]
#  [ 0.80989975]
#  [ 0.9371113 ]
#  [ 1.0688837 ]
#  [ 1.1857325 ]
#  [ 1.2900043 ]
#  [ 1.3619128 ]
#  [ 1.4113576 ]
#  [ 1.449081  ]
#  [ 1.4741611 ]
#  [ 1.487534  ]
#  [ 1.4951539 ]
#  [ 1.4975501 ]
#  [ 1.4948347 ]
#  [ 1.49224   ]
#  [ 1.4898747 ]
#  [ 1.4897293 ]
#  [ 1.4917613 ]
#  [ 1.4938073 ]
#  [ 1.499003  ]
#  [ 1.5073179 ]
#  [ 1.5178131 ]
#  [ 1.5341629 ]
#  [ 1.5515631 ]
#  [ 1.5617443 ]
#  [ 1.5617455 ]
#  [ 1.5484167 ]
#  [ 1.5262774 ]
#  [ 1.4943342 ]
#  [ 1.4414905 ]
#  [ 1.3499428 ]
#  [ 1.21602   ]
#  [ 1.0683093 ]
#  [ 0.92424643]
#  [ 0.77460563]
#  [ 0.61073273]
#  [ 0.44975048]
#  [ 0.30898845]
#  [ 0.18596242]
#  [ 0.09190483]
#  [ 0.03462161]
#  [ 0.00960176]
#  [ 0.02015607]
#  [ 0.06742091]
#  [ 0.15031856]
#  [ 0.26254383]
#  [ 0.39923078]
#  [ 0.55330473]
#  [ 0.730617  ]
#  [ 0.8898841 ]
#  [ 1.0455564 ]
#  [ 1.1871365 ]
#  [ 1.3096433 ]
#  [ 1.3906087 ]
#  [ 1.4509234 ]
#  [ 1.4896847 ]
#  [ 1.511748  ]
#  [ 1.5251932 ]
#  [ 1.5342914 ]
#  [ 1.5407634 ]
#  [ 1.5454037 ]
#  [ 1.5514156 ]
#  [ 1.55765   ]
#  [ 1.5667912 ]
#  [ 1.5750765 ]
#  [ 1.5853932 ]
#  [ 1.5958306 ]
#  [ 1.6048201 ]
#  [ 1.613646  ]
#  [ 1.6219171 ]
#  [ 1.6270592 ]
#  [ 1.6298261 ]
#  [ 1.6240178 ]
#  [ 1.6108682 ]
#  [ 1.5913973 ]
#  [ 1.5631474 ]
#  [ 1.5302451 ]
#  [ 1.4853216 ]
#  [ 1.4075536 ]
#  [ 1.3083924 ]
#  [ 1.1689552 ]
#  [ 1.0334294 ]
#  [ 0.8877522 ]
#  [ 0.7408812 ]
#  [ 0.6057537 ]
#  [ 0.48212856]
#  [ 0.38766128]
#  [ 0.31213033]
#  [ 0.27174377]
#  [ 0.26770496]
#  [ 0.30170318]
#  [ 0.3736158 ]
#  [ 0.48046285]
#  [ 0.59548724]
#  [ 0.72998464]
#  [ 0.8519475 ]
#  [ 0.96392226]
#  [ 1.088662  ]
#  [ 1.2277852 ]
#  [ 1.3559581 ]
#  [ 1.4541166 ]
#  [ 1.5134947 ]
#  [ 1.5526465 ]
#  [ 1.580394  ]
#  [ 1.6015052 ]
#  [ 1.6172844 ]
#  [ 1.6299998 ]
#  [ 1.637773  ]
#  [ 1.6421916 ]
#  [ 1.63926   ]
#  [ 1.6285937 ]
#  [ 1.6125787 ]
#  [ 1.5944785 ]
#  [ 1.5776117 ]
#  [ 1.5654517 ]
#  [ 1.5597196 ]
#  [ 1.5560526 ]
#  [ 1.5568095 ]
#  [ 1.5635234 ]
#  [ 1.5695425 ]
#  [ 1.5691606 ]
#  [ 1.5593352 ]
#  [ 1.5406545 ]
#  [ 1.5134742 ]
#  [ 1.4753677 ]
#  [ 1.4035622 ]
#  [ 1.3067182 ]
#  [ 1.1847029 ]
#  [ 1.0423363 ]]

# %%
#3. Invers to original data
inv_data = scaler.inverse_transform(y_pred)
inv_data
# Out:
# array([[758.00806],
#        [744.45667],
#        [730.4853 ],
#        [716.83746],
#        [704.8518 ],
#        [694.60913],
#        [687.2923 ],
#        [683.02673],
#        [681.70654],
#        [684.2019 ],
#        [689.71533],
#        [698.2231 ],
#        [708.7795 ],
#        [719.7869 ],
#        [731.1901 ],
#        [744.6062 ],
#        [754.99866],
#        [765.5228 ],
#        [777.1405 ],
#        [787.9887 ],
#        [797.3159 ],
#        [803.9789 ],
#        [808.8952 ],
#        [812.2281 ],
#        [814.77423],
#        [816.7417 ],
#        [818.27386],
#        [819.458  ],
#        [820.29535],
#        [820.8698 ],
#        [821.08795],
#        [821.11786],
#        [821.05414],
#        [821.0274 ],
#        [821.02527],
#        [821.02374],
#        [821.25256],
#        [822.0152 ],
#        [822.493  ],
#        [822.2656 ],
#        [821.4811 ],
#        [819.77594],
#        [817.3112 ],
#        [814.1666 ],
#        [810.1316 ],
#        [803.0912 ],
#        [794.6861 ],
#        [781.9907 ],
#        [767.7394 ],
#        [753.10583],
#        [739.0803 ],
#        [724.3251 ],
#        [711.5845 ],
#        [700.92566],
#        [692.7645 ],
#        [687.35406],
#        [684.7928 ],
#        [685.35034],
#        [688.6132 ],
#        [695.81464],
#        [705.3936 ],
#        [718.4636 ],
#        [731.7057 ],
#        [746.4455 ],
#        [759.3965 ],
#        [774.39734],
#        [787.9854 ],
#        [798.9148 ],
#        [806.6431 ],
#        [811.6664 ],
#        [815.2747 ],
#        [817.8007 ],
#        [819.2861 ],
#        [820.40076],
#        [821.26086],
#        [821.8038 ],
#        [822.0667 ],
#        [822.02655],
#        [822.0955 ],
#        [822.11505],
#        [822.07   ],
#        [821.98157],
#        [821.9377 ],
#        [821.9122 ],
#        [822.2623 ],
#        [822.5604 ],
#        [822.77454],
#        [822.2276 ],
#        [820.8753 ],
#        [818.7061 ],
#        [816.081  ],
#        [812.69543],
#        [807.5257 ],
#        [799.85156],
#        [789.51465],
#        [776.8655 ],
#        [764.21423],
#        [752.847  ],
#        [741.06116],
#        [730.7421 ],
#        [721.1596 ],
#        [712.24384],
#        [706.4827 ],
#        [702.888  ],
#        [702.78754],
#        [705.8114 ],
#        [711.93805],
#        [719.64667],
#        [729.2038 ],
#        [739.78674],
#        [748.3208 ],
#        [757.0838 ],
#        [768.82074],
#        [781.9943 ],
#        [794.8722 ],
#        [805.24884],
#        [811.7833 ],
#        [815.90106],
#        [818.6496 ],
#        [820.5767 ],
#        [822.0985 ],
#        [822.8301 ],
#        [823.0892 ],
#        [823.029  ],
#        [822.4087 ],
#        [821.64685],
#        [820.42737],
#        [819.0677 ],
#        [817.8062 ],
#        [816.8669 ],
#        [816.2285 ],
#        [815.91327],
#        [815.7492 ],
#        [816.1068 ],
#        [817.26776],
#        [817.9495 ],
#        [817.7039 ],
#        [816.6046 ],
#        [814.3806 ],
#        [811.0759 ],
#        [806.325  ],
#        [798.36005],
#        [788.30225],
#        [774.2353 ],
#        [760.43475],
#        [744.49286],
#        [728.8926 ],
#        [713.1573 ],
#        [700.1059 ],
#        [690.05756],
#        [682.539  ],
#        [677.8612 ],
#        [676.6101 ],
#        [678.6718 ],
#        [684.5821 ],
#        [693.45135],
#        [705.2454 ],
#        [718.66547],
#        [730.244  ],
#        [739.8966 ],
#        [751.25415],
#        [764.40436],
#        [777.6189 ],
#        [789.75696],
#        [799.2463 ],
#        [805.713  ],
#        [809.2296 ],
#        [811.4304 ],
#        [812.5208 ],
#        [813.16956],
#        [813.4374 ],
#        [813.273  ],
#        [813.29663],
#        [812.92847],
#        [812.39484],
#        [811.9058 ],
#        [811.5375 ],
#        [811.62946],
#        [812.0166 ],
#        [812.662  ],
#        [813.50604],
#        [814.63934],
#        [815.9221 ],
#        [816.3117 ],
#        [815.6524 ],
#        [814.06683],
#        [811.5668 ],
#        [807.6966 ],
#        [801.0237 ],
#        [791.23096],
#        [777.2525 ],
#        [762.50195],
#        [746.5714 ],
#        [729.2909 ],
#        [711.9154 ],
#        [696.11005],
#        [681.94824],
#        [670.5404 ],
#        [661.9039 ],
#        [656.5805 ],
#        [655.1214 ],
#        [657.6661 ],
#        [663.9212 ],
#        [673.7229 ],
#        [685.53064],
#        [698.9679 ],
#        [715.2848 ],
#        [731.163  ],
#        [743.1899 ],
#        [755.8411 ],
#        [768.9459 ],
#        [780.56665],
#        [790.9365 ],
#        [798.0879 ],
#        [803.0052 ],
#        [806.7568 ],
#        [809.25104],
#        [810.581  ],
#        [811.33875],
#        [811.5771 ],
#        [811.307  ],
#        [811.04895],
#        [810.8137 ],
#        [810.79926],
#        [811.00134],
#        [811.20483],
#        [811.72156],
#        [812.54846],
#        [813.5922 ],
#        [815.2182 ],
#        [816.94867],
#        [817.96124],
#        [817.96136],
#        [816.6358 ],
#        [814.434  ],
#        [811.25726],
#        [806.0019 ],
#        [796.89746],
#        [783.57874],
#        [768.88885],
#        [754.5617 ],
#        [739.6798 ],
#        [723.38257],
#        [707.3728 ],
#        [693.37396],
#        [681.1389 ],
#        [671.78485],
#        [666.088  ],
#        [663.5998 ],
#        [664.6494 ],
#        [669.3499 ],
#        [677.5941 ],
#        [688.755  ],
#        [702.3486 ],
#        [717.6713 ],
#        [735.3051 ],
#        [751.14435],
#        [766.62604],
#        [780.70624],
#        [792.88965],
#        [800.94165],
#        [806.94   ],
#        [810.79486],
#        [812.9891 ],
#        [814.3262 ],
#        [815.231  ],
#        [815.87463],
#        [816.3361 ],
#        [816.934  ],
#        [817.554  ],
#        [818.46313],
#        [819.2871 ],
#        [820.3131 ],
#        [821.35114],
#        [822.2451 ],
#        [823.12286],
#        [823.94543],
#        [824.45685],
#        [824.732  ],
#        [824.15436],
#        [822.8466 ],
#        [820.9102 ],
#        [818.10077],
#        [814.8286 ],
#        [810.36096],
#        [802.62683],
#        [792.7652 ],
#        [778.89813],
#        [765.42   ],
#        [750.9323 ],
#        [736.3259 ],
#        [722.8874 ],
#        [710.59283],
#        [701.198  ],
#        [693.6864 ],
#        [689.6699 ],
#        [689.26825],
#        [692.6494 ],
#        [699.80115],
#        [710.4272 ],
#        [721.8664 ],
#        [735.24225],
#        [747.3715 ],
#        [758.50745],
#        [770.9129 ],
#        [784.7488 ],
#        [797.49567],
#        [807.25757],
#        [813.1628 ],
#        [817.05646],
#        [819.8159 ],
#        [821.91547],
#        [823.4847 ],
#        [824.74927],
#        [825.52234],
#        [825.96173],
#        [825.6702 ],
#        [824.60944],
#        [823.0167 ],
#        [821.2167 ],
#        [819.53925],
#        [818.3299 ],
#        [817.7598 ],
#        [817.39514],
#        [817.47046],
#        [818.1381 ],
#        [818.73676],
#        [818.6988 ],
#        [817.7216 ],
#        [815.86383],
#        [813.1607 ],
#        [809.37103],
#        [802.2299 ],
#        [792.59875],
#        [780.46423],
#        [766.3058 ]], dtype=float32)

# %%
#4. Copy Dataframe
viz = df.copy()
viz
# Out:
#                  datetime    load
# 0     2018-01-01 00:30:00  554.80
# 1     2018-01-01 01:00:00  545.80
# 2     2018-01-01 01:30:00  534.70
# 3     2018-01-01 02:00:00  521.50
# 4     2018-01-01 02:30:00  496.50
# ...                   ...     ...
# 35035 2019-12-31 22:00:00  807.81
# 35036 2019-12-31 22:30:00  788.11
# 35037 2019-12-31 23:00:00  773.05
# 35038 2019-12-31 23:30:00  753.55
# 35039 2020-01-01 00:00:00  726.00
#
# [35040 rows x 2 columns]

# %%
#5. Generate new forecasting date
from prophet import Prophet
m = Prophet()

viz = viz.rename(columns={'datetime': 'ds', 'load' : 'y'})

m.fit(viz)
future = m.make_future_dataframe(periods=n_steps, freq='30 min', include_history=False)
future
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1j0940j8/mmdpfpvu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1j0940j8/nit8ommw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1841', 'data', 'file=/tmp/tmp1j0940j8/mmdpfpvu.json', 'init=/tmp/tmp1j0940j8/nit8ommw.json', 'output', 'file=/tmp/tmp1j0940j8/prophet_modela_qkekg_/prophet_model-20230413060105.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:01:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:01:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#                      ds
# 0   2020-01-01 00:30:00
# 1   2020-01-01 01:00:00
# 2   2020-01-01 01:30:00
# 3   2020-01-01 02:00:00
# 4   2020-01-01 02:30:00
# ..                  ...
# 331 2020-01-07 22:00:00
# 332 2020-01-07 22:30:00
# 333 2020-01-07 23:00:00
# 334 2020-01-07 23:30:00
# 335 2020-01-08 00:00:00
#
# [336 rows x 1 columns]

# %%
#6. Merge Forecasting Date and Data
future['load'] = inv_data
future = future.rename(columns={'ds': 'datetime'})
future
# Out:
#                datetime        load
# 0   2020-01-01 00:30:00  758.008057
# 1   2020-01-01 01:00:00  744.456665
# 2   2020-01-01 01:30:00  730.485291
# 3   2020-01-01 02:00:00  716.837463
# 4   2020-01-01 02:30:00  704.851807
# ..                  ...         ...
# 331 2020-01-07 22:00:00  809.371033
# 332 2020-01-07 22:30:00  802.229919
# 333 2020-01-07 23:00:00  792.598755
# 334 2020-01-07 23:30:00  780.464233
# 335 2020-01-08 00:00:00  766.305786
#
# [336 rows x 2 columns]

# %%
#7. Copy historical data for Visualization
history_predict = n_steps #Set by window_size, 48 = 1 Day

hist_data = df.copy()
hist_data

start_index = len(hist_data) - history_predict
hist_data = hist_data[start_index:]

# %%
len(hist_data)
# Out:
# 48

# %%
hist_data.tail(50)
# Out:
#                  datetime    load
# 34992 2019-12-31 00:30:00  752.90
# 34993 2019-12-31 01:00:00  735.00
# 34994 2019-12-31 01:30:00  718.11
# 34995 2019-12-31 02:00:00  706.46
# 34996 2019-12-31 02:30:00  692.98
# 34997 2019-12-31 03:00:00  677.04
# 34998 2019-12-31 03:30:00  669.84
# 34999 2019-12-31 04:00:00  664.78
# 35000 2019-12-31 04:30:00  665.44
# 35001 2019-12-31 05:00:00  668.89
# 35002 2019-12-31 05:30:00  680.42
# 35003 2019-12-31 06:00:00  683.71
# 35004 2019-12-31 06:30:00  689.92
# 35005 2019-12-31 07:00:00  707.35
# 35006 2019-12-31 07:30:00  745.47
# 35007 2019-12-31 08:00:00  781.94
# 35008 2019-12-31 08:30:00  838.62
# 35009 2019-12-31 09:00:00  867.38
# 35010 2019-12-31 09:30:00  894.29
# 35011 2019-12-31 10:00:00  907.99
# 35012 2019-12-31 10:30:00  908.29
# 35013 2019-12-31 11:00:00  909.06
# 35014 2019-12-31 11:30:00  913.76
# 35015 2019-12-31 12:00:00  906.82
# 35016 2019-12-31 12:30:00  915.29
# 35017 2019-12-31 13:00:00  910.85
# 35018 2019-12-31 13:30:00  913.64
# 35019 2019-12-31 14:00:00  899.18
# 35020 2019-12-31 14:30:00  871.83
# 35021 2019-12-31 15:00:00  848.17
# 35022 2019-12-31 15:30:00  830.34
# 35023 2019-12-31 16:00:00  826.54
# 35024 2019-12-31 16:30:00  825.26
# 35025 2019-12-31 17:00:00  825.29
# 35026 2019-12-31 17:30:00  818.92
# 35027 2019-12-31 18:00:00  827.47
# 35028 2019-12-31 18:30:00  858.42
# 35029 2019-12-31 19:00:00  897.37
# 35030 2019-12-31 19:30:00  894.51
# 35031 2019-12-31 20:00:00  881.38
# 35032 2019-12-31 20:30:00  865.26
# 35033 2019-12-31 21:00:00  850.45
# 35034 2019-12-31 21:30:00  831.64
# 35035 2019-12-31 22:00:00  807.81
# 35036 2019-12-31 22:30:00  788.11
# 35037 2019-12-31 23:00:00  773.05
# 35038 2019-12-31 23:30:00  753.55
# 35039 2020-01-01 00:00:00  726.00

# %%
#8. Set Index
hist_data = hist_data.set_index('datetime')
future_data = future.set_index('datetime')

# %%
future_data
# Out:
#                            load
# datetime
# 2020-01-01 00:30:00  758.008057
# 2020-01-01 01:00:00  744.456665
# 2020-01-01 01:30:00  730.485291
# 2020-01-01 02:00:00  716.837463
# 2020-01-01 02:30:00  704.851807
# ...                         ...
# 2020-01-07 22:00:00  809.371033
# 2020-01-07 22:30:00  802.229919
# 2020-01-07 23:00:00  792.598755
# 2020-01-07 23:30:00  780.464233
# 2020-01-08 00:00:00  766.305786
#
# [336 rows x 1 columns]

# %%
#9. Visualization

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15, 5))
hist_data.plot(ax=ax, label='Training Data', title='Observed Data')
future_data.plot(ax=ax, label='Predicted')
ax.axvline('2020-01-01', color='black', ls='--')
ax.legend(['Training Set', 'Predicted'])
plt.show()
