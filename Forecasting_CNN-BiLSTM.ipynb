# %% [markdown]
# #CNN-BiLSTM
#
# Sudah sampai evaluasi 1, 3, 7 RMSE dan CC
#
# Cara Running Load Model
# 1. Import
# 2. Read Data
# 3. Split Data
# 4. Normalisasi pakai Standart Scaler
# 5. Pisah tanggal untuk forecast day 1, 3, 7.
# 6. Membuat fungsi sliding window
# 7. Mengaktifkan fungsi ke X, y
# 8. Membuat fungsi CC dan Load Model
# 9. Evaluasi pada Day 1, 3, 7 dengan RMSE dan CC
# 10. Membuat Dataframe dari Predicted value (y_pred)
# 11. Visualisasi Day 1, 3, 7

# %%
#Step 1
import numpy as np
import joblib
import pandas as pd
import datetime
import tensorflow as tf
import os
import random
import timeit
import seaborn as sns
import datetime
import matplotlib.pyplot as plt

import tensorflow_probability as tfp
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, Bidirectional, Dropout
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import RootMeanSquaredError

# %%
#Step 2
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_excel('/content/drive/MyDrive/databeban_merged.xlsx')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = df.set_index('datetime')
df.index = pd.to_datetime(df.index)

# %%
df
# Out:
#                        load
# datetime
# 2018-01-01 00:30:00  554.80
# 2018-01-01 01:00:00  545.80
# 2018-01-01 01:30:00  534.70
# 2018-01-01 02:00:00  521.50
# 2018-01-01 02:30:00  496.50
# ...                     ...
# 2019-12-31 22:00:00  807.81
# 2019-12-31 22:30:00  788.11
# 2019-12-31 23:00:00  773.05
# 2019-12-31 23:30:00  753.55
# 2020-01-01 00:00:00  726.00
#
# [35040 rows x 1 columns]

# %%
#Step 3
# Split the data into training, validation, and test sets
n = len(df)
n_train = int(0.8 * n)
n_val = int(0.1 * n)
n_test = n - n_train - n_val

train_data = df[:n_train].drop(columns=['datetime']).values
train_date = df[:n_train].drop(columns=['load'])

val_data   = df[n_train:n_train+n_val].drop(columns=['datetime']).values
val_date   = df[n_train:n_train+n_val].drop(columns=['load'])

test_data  = df[-n_test:].drop(columns=['datetime']).values
test_date  = df[-n_test:].drop(columns=['load'])

# %%
test_date
# Out:
#                  datetime
# 31536 2019-10-20 00:30:00
# 31537 2019-10-20 01:00:00
# 31538 2019-10-20 01:30:00
# 31539 2019-10-20 02:00:00
# 31540 2019-10-20 02:30:00
# ...                   ...
# 35035 2019-12-31 22:00:00
# 35036 2019-12-31 22:30:00
# 35037 2019-12-31 23:00:00
# 35038 2019-12-31 23:30:00
# 35039 2020-01-01 00:00:00
#
# [3504 rows x 1 columns]

# %%
print('Train Set      : ',len(train_data))
print('Validation Set : ',len(val_data))
print('Test Set       : ',len(test_data))
# Out:
# Train Set      :  28032
# Validation Set :  3504
# Test Set       :  3504

# %%
#Step 4
# Normalize the data using StandardScaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_data = scaler.fit_transform(train_data)
val_data   = scaler.transform(val_data)
test_data  = scaler.transform(test_data)

# %%
#Step 5
#Take day for predict from data test, 48 = 1 day

one_day_date = test_date.head(48)
one_day_data = test_data[:48]

three_day_date = test_date.head(144)
three_day_data = test_data[:144]

seven_day_date = test_date.head(336)
seven_day_data = test_data[:336]

# %%
#Step 6 
#Create a windowed dataset for training
window_size = 48 # (1 weeks) use 48 from interval one day of data for each window
def create_window_dataset(data, window_size):
    X = []
    y = []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i])
        y.append(data[i])
    return np.array(X), np.array(y)

# %%
train_data
# Out:
# array([[-1.08440691],
#        [-1.17490414],
#        [-1.2865174 ],
#        ...,
#        [-0.52875391],
#        [-0.83171853],
#        [-1.01814283]])

# %%
original_data = scaler.inverse_transform(train_data)
original_data
# Out:
# array([[554.8 ],
#        [545.8 ],
#        [534.7 ],
#        ...,
#        [610.06],
#        [579.93],
#        [561.39]])

# %%
#Step 7
X_train, y_train = create_window_dataset(train_data, window_size)
X_val, y_val     = create_window_dataset(val_data, window_size)
X_test, y_test   = create_window_dataset(test_data, window_size)

# %%
#Step 8
def cc(y_true, y_pred):
    """
    Compute the correlation coefficient between y_true and y_pred.
    """
    # Compute the covariance matrix
    cov = tfp.stats.covariance(y_true, y_pred, sample_axis=0)

    # Compute the standard deviation of y_true and y_pred
    std_true = K.std(y_true)
    std_pred = K.std(y_pred)

    # Compute the correlation coefficient
    return cov / (std_true * std_pred)

# %%
#Step 8
from keras.models import load_model
import pickle

# Load the trained model
model = load_model('/content/drive/MyDrive/Model/CNN-BiLSTM_Model_Final.h5', custom_objects={"cc": cc })

# Load the history object
with open('/content/drive/MyDrive/Model/CNN-BiLSTM_history_Final.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
input_shape = (window_size, 1)

model = Sequential([
    Conv1D(filters=8, kernel_size=1, activation='relu', input_shape=input_shape),
    Conv1D(filters=8, kernel_size=1, activation='relu'),
    MaxPooling1D(pool_size=2),

    Bidirectional(LSTM(64, return_sequences=True)),
    Dropout(0.5),
    Bidirectional(LSTM(64)),

    Dense(32, activation='relu'),
    Dense(1)
])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
model.compile(optimizer= optimizer, 
              loss=tf.keras.losses.Huber(), 
              metrics= [RootMeanSquaredError(), cc])

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', 
                               patience=5, verbose=1,
                               mode='min', 
                               restore_best_weights=True)

# %%
history = model.fit(
    X_train, y_train, 
    epochs=50, 
    batch_size=16, 
    validation_data=(X_val, y_val), 
    callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 1749/1749 [==============================] - 119s 64ms/step - loss: 0.1047 - root_mean_squared_error: 0.4698 - cc: 0.9163 - val_loss: 0.0339 - val_root_mean_squared_error: 0.2605 - val_cc: 0.9065
# Epoch 2/50
# 1749/1749 [==============================] - 105s 60ms/step - loss: 0.0424 - root_mean_squared_error: 0.2986 - cc: 0.9557 - val_loss: 0.0233 - val_root_mean_squared_error: 0.2160 - val_cc: 0.9296
# Epoch 3/50
# 1749/1749 [==============================] - 101s 58ms/step - loss: 0.0352 - root_mean_squared_error: 0.2730 - cc: 0.9632 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1915 - val_cc: 0.9440
# Epoch 4/50
# 1749/1749 [==============================] - 107s 61ms/step - loss: 0.0304 - root_mean_squared_error: 0.2545 - cc: 0.9686 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1821 - val_cc: 0.9493
# Epoch 5/50
# 1749/1749 [==============================] - 101s 58ms/step - loss: 0.0273 - root_mean_squared_error: 0.2414 - cc: 0.9724 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1675 - val_cc: 0.9463
# Epoch 6/50
# 1749/1749 [==============================] - 103s 59ms/step - loss: 0.0252 - root_mean_squared_error: 0.2318 - cc: 0.9745 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1701 - val_cc: 0.9430
# Epoch 7/50
# 1749/1749 [==============================] - 103s 59ms/step - loss: 0.0237 - root_mean_squared_error: 0.2252 - cc: 0.9754 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1542 - val_cc: 0.9413
# Epoch 8/50
# 1749/1749 [==============================] - 104s 59ms/step - loss: 0.0227 - root_mean_squared_error: 0.2204 - cc: 0.9768 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1496 - val_cc: 0.9399
# Epoch 9/50
# 1749/1749 [==============================] - 99s 57ms/step - loss: 0.0217 - root_mean_squared_error: 0.2153 - cc: 0.9779 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1511 - val_cc: 0.9384
# Epoch 10/50
# 1749/1749 [==============================] - 102s 58ms/step - loss: 0.0210 - root_mean_squared_error: 0.2123 - cc: 0.9784 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1448 - val_cc: 0.9371
# Epoch 11/50
# 1749/1749 [==============================] - 103s 59ms/step - loss: 0.0204 - root_mean_squared_error: 0.2094 - cc: 0.9794 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1475 - val_cc: 0.9381
# Epoch 12/50
# 1749/1749 [==============================] - 101s 58ms/step - loss: 0.0196 - root_mean_squared_error: 0.2053 - cc: 0.9802 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1460 - val_cc: 0.9380
# Epoch 13/50
# 1749/1749 [==============================] - 102s 58ms/step - loss: 0.0194 - root_mean_squared_error: 0.2046 - cc: 0.9806 - val_loss: 0.0095 - val_root_mean_squared_error: 0.1380 - val_cc: 0.9406
# Epoch 14/50
# 1749/1749 [==============================] - 105s 60ms/step - loss: 0.0188 - root_mean_squared_error: 0.2016 - cc: 0.9809 - val_loss: 0.0094 - val_root_mean_squared_error: 0.1369 - val_cc: 0.9407
# Epoch 15/50
# 1749/1749 [==============================] - 102s 58ms/step - loss: 0.0186 - root_mean_squared_error: 0.2001 - cc: 0.9813 - val_loss: 0.0096 - val_root_mean_squared_error: 0.1386 - val_cc: 0.9375
# Epoch 16/50
# 1749/1749 [==============================] - 102s 58ms/step - loss: 0.0182 - root_mean_squared_error: 0.1980 - cc: 0.9817 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1418 - val_cc: 0.9372
# Epoch 17/50
# 1749/1749 [==============================] - 101s 58ms/step - loss: 0.0179 - root_mean_squared_error: 0.1963 - cc: 0.9820 - val_loss: 0.0093 - val_root_mean_squared_error: 0.1367 - val_cc: 0.9410
# Epoch 18/50
# 1749/1749 [==============================] - 100s 57ms/step - loss: 0.0174 - root_mean_squared_error: 0.1937 - cc: 0.9824 - val_loss: 0.0091 - val_root_mean_squared_error: 0.1349 - val_cc: 0.9416
# Epoch 19/50
# 1749/1749 [==============================] - 101s 58ms/step - loss: 0.0173 - root_mean_squared_error: 0.1931 - cc: 0.9828 - val_loss: 0.0094 - val_root_mean_squared_error: 0.1373 - val_cc: 0.9405
# Epoch 20/50
# 1749/1749 [==============================] - 100s 57ms/step - loss: 0.0169 - root_mean_squared_error: 0.1910 - cc: 0.9830 - val_loss: 0.0089 - val_root_mean_squared_error: 0.1333 - val_cc: 0.9431
# Epoch 21/50
# 1749/1749 [==============================] - 102s 58ms/step - loss: 0.0167 - root_mean_squared_error: 0.1899 - cc: 0.9830 - val_loss: 0.0086 - val_root_mean_squared_error: 0.1308 - val_cc: 0.9436
# Epoch 22/50
# 1749/1749 [==============================] - 99s 57ms/step - loss: 0.0164 - root_mean_squared_error: 0.1881 - cc: 0.9835 - val_loss: 0.0086 - val_root_mean_squared_error: 0.1314 - val_cc: 0.9433
# Epoch 23/50
# 1749/1749 [==============================] - 99s 56ms/step - loss: 0.0163 - root_mean_squared_error: 0.1872 - cc: 0.9838 - val_loss: 0.0081 - val_root_mean_squared_error: 0.1277 - val_cc: 0.9444
# Epoch 24/50
# 1749/1749 [==============================] - 99s 57ms/step - loss: 0.0161 - root_mean_squared_error: 0.1861 - cc: 0.9837 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1254 - val_cc: 0.9463
# Epoch 25/50
# 1749/1749 [==============================] - 100s 57ms/step - loss: 0.0157 - root_mean_squared_error: 0.1842 - cc: 0.9841 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1238 - val_cc: 0.9453
# Epoch 26/50
# 1749/1749 [==============================] - 103s 59ms/step - loss: 0.0156 - root_mean_squared_error: 0.1841 - cc: 0.9843 - val_loss: 0.0081 - val_root_mean_squared_error: 0.1270 - val_cc: 0.9489
# Epoch 27/50
# 1749/1749 [==============================] - 100s 57ms/step - loss: 0.0154 - root_mean_squared_error: 0.1823 - cc: 0.9848 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1228 - val_cc: 0.9488
# Epoch 28/50
# 1749/1749 [==============================] - 100s 57ms/step - loss: 0.0151 - root_mean_squared_error: 0.1810 - cc: 0.9847 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1209 - val_cc: 0.9505
# Epoch 29/50
# 1749/1749 [==============================] - 103s 59ms/step - loss: 0.0149 - root_mean_squared_error: 0.1803 - cc: 0.9848 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1229 - val_cc: 0.9503
# Epoch 30/50
# 1749/1749 [==============================] - 100s 57ms/step - loss: 0.0148 - root_mean_squared_error: 0.1795 - cc: 0.9851 - val_loss: 0.0069 - val_root_mean_squared_error: 0.1178 - val_cc: 0.9532
# Epoch 31/50
# 1749/1749 [==============================] - 101s 58ms/step - loss: 0.0145 - root_mean_squared_error: 0.1779 - cc: 0.9855 - val_loss: 0.0068 - val_root_mean_squared_error: 0.1170 - val_cc: 0.9543
# Epoch 32/50
# 1749/1749 [==============================] - 104s 59ms/step - loss: 0.0145 - root_mean_squared_error: 0.1771 - cc: 0.9853 - val_loss: 0.0071 - val_root_mean_squared_error: 0.1193 - val_cc: 0.9550
# Epoch 33/50
# 1749/1749 [==============================] - 101s 58ms/step - loss: 0.0142 - root_mean_squared_error: 0.1754 - cc: 0.9857 - val_loss: 0.0067 - val_root_mean_squared_error: 0.1157 - val_cc: 0.9548
# Epoch 34/50
# 1749/1749 [==============================] - 101s 57ms/step - loss: 0.0141 - root_mean_squared_error: 0.1747 - cc: 0.9860 - val_loss: 0.0067 - val_root_mean_squared_error: 0.1157 - val_cc: 0.9556
# Epoch 35/50
# 1749/1749 [==============================] - 101s 58ms/step - loss: 0.0138 - root_mean_squared_error: 0.1737 - cc: 0.9862 - val_loss: 0.0065 - val_root_mean_squared_error: 0.1142 - val_cc: 0.9570
# Epoch 36/50
# 1749/1749 [==============================] - 104s 59ms/step - loss: 0.0138 - root_mean_squared_error: 0.1731 - cc: 0.9860 - val_loss: 0.0062 - val_root_mean_squared_error: 0.1114 - val_cc: 0.9565
# Epoch 37/50
# 1749/1749 [==============================] - 102s 59ms/step - loss: 0.0136 - root_mean_squared_error: 0.1718 - cc: 0.9864 - val_loss: 0.0061 - val_root_mean_squared_error: 0.1106 - val_cc: 0.9592
# Epoch 38/50
# 1749/1749 [==============================] - 101s 58ms/step - loss: 0.0135 - root_mean_squared_error: 0.1711 - cc: 0.9864 - val_loss: 0.0061 - val_root_mean_squared_error: 0.1105 - val_cc: 0.9587
# Epoch 39/50
# 1749/1749 [==============================] - 104s 60ms/step - loss: 0.0133 - root_mean_squared_error: 0.1702 - cc: 0.9865 - val_loss: 0.0057 - val_root_mean_squared_error: 0.1069 - val_cc: 0.9614
# Epoch 40/50
# 1749/1749 [==============================] - 102s 58ms/step - loss: 0.0132 - root_mean_squared_error: 0.1696 - cc: 0.9867 - val_loss: 0.0057 - val_root_mean_squared_error: 0.1069 - val_cc: 0.9614
# Epoch 41/50
# 1749/1749 [==============================] - 104s 59ms/step - loss: 0.0130 - root_mean_squared_error: 0.1682 - cc: 0.9870 - val_loss: 0.0058 - val_root_mean_squared_error: 0.1079 - val_cc: 0.9621
# Epoch 42/50
# 1749/1749 [==============================] - 103s 59ms/step - loss: 0.0129 - root_mean_squared_error: 0.1679 - cc: 0.9869 - val_loss: 0.0055 - val_root_mean_squared_error: 0.1045 - val_cc: 0.9628
# Epoch 43/50
# 1749/1749 [==============================] - 101s 58ms/step - loss: 0.0128 - root_mean_squared_error: 0.1677 - cc: 0.9871 - val_loss: 0.0052 - val_root_mean_squared_error: 0.1018 - val_cc: 0.9640
# Epoch 44/50
# 1749/1749 [==============================] - 102s 58ms/step - loss: 0.0127 - root_mean_squared_error: 0.1663 - cc: 0.9873 - val_loss: 0.0067 - val_root_mean_squared_error: 0.1159 - val_cc: 0.9633
# Epoch 45/50
# 1749/1749 [==============================] - 103s 59ms/step - loss: 0.0126 - root_mean_squared_error: 0.1655 - cc: 0.9875 - val_loss: 0.0052 - val_root_mean_squared_error: 0.1016 - val_cc: 0.9648
# Epoch 46/50
# 1749/1749 [==============================] - 105s 60ms/step - loss: 0.0125 - root_mean_squared_error: 0.1653 - cc: 0.9875 - val_loss: 0.0051 - val_root_mean_squared_error: 0.1013 - val_cc: 0.9656
# Epoch 47/50
# 1749/1749 [==============================] - 106s 61ms/step - loss: 0.0123 - root_mean_squared_error: 0.1643 - cc: 0.9876 - val_loss: 0.0054 - val_root_mean_squared_error: 0.1036 - val_cc: 0.9649
# Epoch 48/50
# 1749/1749 [==============================] - 103s 59ms/step - loss: 0.0122 - root_mean_squared_error: 0.1633 - cc: 0.9879 - val_loss: 0.0052 - val_root_mean_squared_error: 0.1024 - val_cc: 0.9658
# Epoch 49/50
# 1749/1749 [==============================] - 103s 59ms/step - loss: 0.0122 - root_mean_squared_error: 0.1630 - cc: 0.9879 - val_loss: 0.0051 - val_root_mean_squared_error: 0.1009 - val_cc: 0.9667
# Epoch 50/50
# 1749/1749 [==============================] - 107s 61ms/step - loss: 0.0121 - root_mean_squared_error: 0.1622 - cc: 0.9877 - val_loss: 0.0051 - val_root_mean_squared_error: 0.1012 - val_cc: 0.9667

# %%
# Plot the training and validation metrics
plt.plot(history['loss'], label='Training loss')
plt.plot(history['val_loss'], label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
plt.plot(history['root_mean_squared_error'], label='Training RMSE')
plt.plot(history['val_root_mean_squared_error'], label='Validation RMSE')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
plt.plot(history['cc'], label='Training CC')
plt.plot(history['val_cc'], label='Validation CC')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Evaluate the model on the test set
test_loss, test_rmse, test_cc = model.evaluate(X_test, y_test)

# Make predictions on the test set
y_pred = model.predict(X_test)
# Out:
# 108/108 [==============================] - 7s 22ms/step - loss: 0.0172 - root_mean_squared_error: 0.1854 - cc: 0.9701
# 108/108 [==============================] - 4s 17ms/step

# %%
# Plot the predicted and true labels
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
plt.plot(y_test, label='True Labels')
plt.plot(y_pred, label='Predicted Labels')
plt.legend()
plt.show()

# %%
#Step 9
#Evaluate the model on the 1, 3, 7 Days to Forecast
X_one   = X_test[:48]
X_three = X_test[:144]
X_seven = X_test[:336]

y_one   = y_test[:48]
y_three = y_test[:144]
y_seven = y_test[:336]

print("1 Day to Forecast")
test_loss, test_rmse, test_cc = model.evaluate(X_one, y_one)
y_pred_one = model.predict(X_one)


print("3 Days to Forecast")
test_loss, test_rmse, test_cc = model.evaluate(X_three, y_three)
y_pred_three = model.predict(X_three)

print("7 Days to Forecast")
test_loss, test_rmse, test_cc = model.evaluate(X_seven, y_seven)
y_pred_seven = model.predict(X_seven)
# Out:
# 1 Day to Forecast
# 2/2 [==============================] - 2s 26ms/step - loss: 0.0130 - root_mean_squared_error: 0.1614 - cc: 0.9923
# 2/2 [==============================] - 2s 16ms/step
# 3 Days to Forecast
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0091 - root_mean_squared_error: 0.1350 - cc: 0.9883
# 5/5 [==============================] - 0s 19ms/step
# 7 Days to Forecast
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0080 - root_mean_squared_error: 0.1264 - cc: 0.9871
# 11/11 [==============================] - 0s 17ms/step

# %%
#Step 10
#Inverse from scaled data
inv_pred_one = scaler.inverse_transform(y_pred_one)
inv_one      = scaler.inverse_transform(y_one)

inv_pred_three = scaler.inverse_transform(y_pred_three)
inv_three      = scaler.inverse_transform(y_three)

inv_pred_seven = scaler.inverse_transform(y_pred_seven)
inv_seven      = scaler.inverse_transform(y_seven)

#Copy data date
viz_one   = one_day_date.copy()
viz_three = three_day_date.copy()
viz_seven = seven_day_date.copy()

#Join true and predicted data
viz_one['load_pred'] = inv_pred_one
viz_one['load_true'] = inv_one

viz_three['load_pred'] = inv_pred_three
viz_three['load_true'] = inv_three

viz_seven['load_pred'] = inv_pred_seven
viz_seven['load_true'] = inv_seven

# %%
#1 Day Forecasting

# Load dataset
viz_one = viz_one.set_index('datetime')

# Plot two columns in one chart
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(viz_one.index, viz_one['load_pred'], label='Predicted')
ax.plot(viz_one.index, viz_one['load_true'], label='True Label')

# Add labels and legend
ax.set_xlabel('Datetime')
ax.set_ylabel('Load Electricity')
ax.set_title('1 Day Forecasting')
ax.legend()

# Show plot
plt.show()

# %%
#3 Days Forecasting

# Load dataset
viz_three = viz_three.set_index('datetime')

# Plot two columns in one chart
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(viz_three.index, viz_three['load_pred'], label='Predicted')
ax.plot(viz_three.index, viz_three['load_true'], label='True Label')

# Add labels and legend
ax.set_xlabel('Datetime')
ax.set_ylabel('Load Electricity')
ax.set_title('3 Days Forecasting')
ax.legend()

# Show plot
plt.show()

# %%
#7 Days Forecasting

# Load dataset
viz_seven = viz_seven.set_index('datetime')

# Plot two columns in one chart
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(viz_seven.index, viz_seven['load_pred'], label='Predicted')
ax.plot(viz_seven.index, viz_seven['load_true'], label='True Label')

# Add labels and legend
ax.set_xlabel('Datetime')
ax.set_ylabel('Load Electricity')
ax.set_title('7 Days Forecasting')
ax.legend()

# Show plot
plt.show()

# %%
import pickle

# Save the trained model
model.save('/content/drive/MyDrive/Model/CNN-BiLSTM_Model_Final.h5')

# Save the history object
with open('/content/drive/MyDrive/Model/CNN-BiLSTM_history_Final.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
model_load.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (None, 128)              33792
#  nal)
#
#  dense_8 (Dense)             (None, 32)                4128
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 37,953
# Trainable params: 37,953
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
len(y_test)
# Out:
# 3432

# %% [markdown]
# #Use Model To Forecasting
#
# Load Library, Model, and Addition First

# %%
#1. Merge array data for base predict
x_data = np.vstack((X_train, X_val, X_test))
x_data
# Out:
# array([[[-1.08440691],
#         [-1.17490414],
#         [-1.2865174 ],
#         ...,
#         [-0.36847326],
#         [-0.64700363],
#         [-0.93558924]],
#
#        [[-1.17490414],
#         [-1.2865174 ],
#         [-1.41924667],
#         ...,
#         [-0.64700363],
#         [-0.93558924],
#         [-1.13870525]],
#
#        [[-1.2865174 ],
#         [-1.41924667],
#         [-1.67062787],
#         ...,
#         [-0.93558924],
#         [-1.13870525],
#         [-1.20808646]],
#
#        ...,
#
#        [[ 1.75489344],
#         [ 1.45223048],
#         [ 1.23443381],
#         ...,
#         [ 1.69928792],
#         [ 1.45967136],
#         [ 1.26158298]],
#
#        [[ 1.45223048],
#         [ 1.23443381],
#         [ 0.9075377 ],
#         ...,
#         [ 1.45967136],
#         [ 1.26158298],
#         [ 1.11015094]],
#
#        [[ 1.23443381],
#         [ 0.9075377 ],
#         [ 0.72754876],
#         ...,
#         [ 1.26158298],
#         [ 1.11015094],
#         [ 0.91407361]]])

# %%
len(val_data)
# Out:
# 3504

# %%
x_data.shape
# Out:
# (34896, 48, 1)

# %%
#2. test model prediction
import numpy as np

# Set the window size and n_steps
n_steps = 48*7 # 7 days

# Get the last window_size data points
start_index = len(x_data) - n_steps
n_step = x_data[start_index:]

# Make the predictions
y_pred = model.predict(n_step)

# Print the predicted values
print(y_pred)
# Out:
# 11/11 [==============================] - 2s 13ms/step
# [[ 1.0174966 ]
#  [ 0.8190018 ]
#  [ 0.6705851 ]
#  [ 0.49082926]
#  [ 0.34337157]
#  [ 0.18718278]
#  [ 0.06440816]
#  [-0.03968431]
#  [-0.09557682]
#  [-0.13350767]
#  [-0.10232222]
#  [-0.0041604 ]
#  [ 0.08046162]
#  [ 0.1816796 ]
#  [ 0.3262772 ]
#  [ 0.63039553]
#  [ 0.9306459 ]
#  [ 1.2372664 ]
#  [ 1.5549045 ]
#  [ 1.7542294 ]
#  [ 1.9258718 ]
#  [ 2.0107784 ]
#  [ 2.0681355 ]
#  [ 2.1186376 ]
#  [ 2.144033  ]
#  [ 2.1674008 ]
#  [ 2.165475  ]
#  [ 2.206586  ]
#  [ 2.2141652 ]
#  [ 2.2412405 ]
#  [ 2.231954  ]
#  [ 2.1991906 ]
#  [ 2.1650481 ]
#  [ 2.1123035 ]
#  [ 2.0543404 ]
#  [ 2.0048456 ]
#  [ 1.9959728 ]
#  [ 2.1396875 ]
#  [ 2.271883  ]
#  [ 2.3134198 ]
#  [ 2.3787851 ]
#  [ 2.4167838 ]
#  [ 2.4046798 ]
#  [ 2.2829256 ]
#  [ 2.1016655 ]
#  [ 1.8130193 ]
#  [ 1.5885359 ]
#  [ 1.3412355 ]
#  [ 1.0986471 ]
#  [ 0.8736942 ]
#  [ 0.6197127 ]
#  [ 0.4413086 ]
#  [ 0.22933827]
#  [ 0.10919985]
#  [-0.02366218]
#  [-0.09699214]
#  [-0.15265149]
#  [-0.14554146]
#  [-0.12304389]
#  [-0.01761171]
#  [ 0.05754897]
#  [ 0.2302343 ]
#  [ 0.42776543]
#  [ 0.8108556 ]
#  [ 1.1979554 ]
#  [ 1.6400049 ]
#  [ 1.8841542 ]
#  [ 2.0890446 ]
#  [ 2.2119164 ]
#  [ 2.3207693 ]
#  [ 2.409236  ]
#  [ 2.44416   ]
#  [ 2.4715528 ]
#  [ 2.4473715 ]
#  [ 2.46108   ]
#  [ 2.4649625 ]
#  [ 2.4564724 ]
#  [ 2.4311109 ]
#  [ 2.4074001 ]
#  [ 2.384019  ]
#  [ 2.3475304 ]
#  [ 2.2915525 ]
#  [ 2.1971407 ]
#  [ 2.1471992 ]
#  [ 2.146165  ]
#  [ 2.2232742 ]
#  [ 2.3636017 ]
#  [ 2.4245296 ]
#  [ 2.5129833 ]
#  [ 2.4900432 ]
#  [ 2.4042277 ]
#  [ 2.2809277 ]
#  [ 2.0522966 ]
#  [ 1.8645602 ]
#  [ 1.6198175 ]
#  [ 1.430137  ]
#  [ 1.2014827 ]
#  [ 1.0235487 ]
#  [ 0.8636362 ]
#  [ 0.6590859 ]
#  [ 0.5045402 ]
#  [ 0.33166587]
#  [ 0.16868512]
#  [ 0.09902631]
#  [-0.0080725 ]
#  [ 0.01508099]
#  [ 0.02948564]
#  [ 0.14090854]
#  [ 0.21069112]
#  [ 0.36777288]
#  [ 0.5418006 ]
#  [ 0.87992966]
#  [ 1.2462052 ]
#  [ 1.6275058 ]
#  [ 1.8801392 ]
#  [ 2.071389  ]
#  [ 2.2106833 ]
#  [ 2.2957263 ]
#  [ 2.3544688 ]
#  [ 2.3789105 ]
#  [ 2.3977032 ]
#  [ 2.3956876 ]
#  [ 2.3638802 ]
#  [ 2.3312116 ]
#  [ 2.3109694 ]
#  [ 2.2056737 ]
#  [ 2.1456366 ]
#  [ 2.004149  ]
#  [ 1.9209071 ]
#  [ 1.8119534 ]
#  [ 1.7550653 ]
#  [ 1.7039043 ]
#  [ 1.7167636 ]
#  [ 1.8280313 ]
#  [ 2.071429  ]
#  [ 2.1512723 ]
#  [ 2.2377071 ]
#  [ 2.267744  ]
#  [ 2.2438216 ]
#  [ 2.1585593 ]
#  [ 1.9690018 ]
#  [ 1.749369  ]
#  [ 1.4962543 ]
#  [ 1.242989  ]
#  [ 1.004379  ]
#  [ 0.7532177 ]
#  [ 0.4476611 ]
#  [ 0.28431207]
#  [ 0.04277617]
#  [-0.05347718]
#  [-0.17850846]
#  [-0.20482033]
#  [-0.24482173]
#  [-0.21388018]
#  [-0.17776233]
#  [-0.07351699]
#  [ 0.05408987]
#  [ 0.21051791]
#  [ 0.39131108]
#  [ 0.66506475]
#  [ 0.96681243]
#  [ 1.3421865 ]
#  [ 1.6037346 ]
#  [ 1.8248423 ]
#  [ 1.975893  ]
#  [ 2.0832267 ]
#  [ 2.1215396 ]
#  [ 2.1777997 ]
#  [ 2.173483  ]
#  [ 2.1636086 ]
#  [ 2.1591964 ]
#  [ 2.1568456 ]
#  [ 2.129959  ]
#  [ 2.0981193 ]
#  [ 1.9915673 ]
#  [ 1.8770218 ]
#  [ 1.7769516 ]
#  [ 1.6904677 ]
#  [ 1.6553247 ]
#  [ 1.6331986 ]
#  [ 1.7335998 ]
#  [ 1.9410506 ]
#  [ 2.2729235 ]
#  [ 2.3498654 ]
#  [ 2.342183  ]
#  [ 2.2505379 ]
#  [ 2.0915456 ]
#  [ 1.901614  ]
#  [ 1.6673478 ]
#  [ 1.4845504 ]
#  [ 1.2636387 ]
#  [ 1.0306076 ]
#  [ 0.78096235]
#  [ 0.57686937]
#  [ 0.34473753]
#  [ 0.18103483]
#  [-0.00988573]
#  [-0.14911008]
#  [-0.2719519 ]
#  [-0.32540518]
#  [-0.37158424]
#  [-0.33612204]
#  [-0.2954873 ]
#  [-0.20114285]
#  [-0.10765246]
#  [ 0.03978783]
#  [ 0.22395846]
#  [ 0.49856928]
#  [ 0.83978844]
#  [ 1.1863859 ]
#  [ 1.495948  ]
#  [ 1.66495   ]
#  [ 1.8344945 ]
#  [ 1.9146394 ]
#  [ 1.9586803 ]
#  [ 2.0171642 ]
#  [ 2.023913  ]
#  [ 2.0104656 ]
#  [ 1.98602   ]
#  [ 1.9675434 ]
#  [ 1.9305738 ]
#  [ 1.865492  ]
#  [ 1.801809  ]
#  [ 1.6876459 ]
#  [ 1.644959  ]
#  [ 1.5656298 ]
#  [ 1.5386755 ]
#  [ 1.537106  ]
#  [ 1.6165897 ]
#  [ 1.8319908 ]
#  [ 2.1536283 ]
#  [ 2.324244  ]
#  [ 2.4316602 ]
#  [ 2.39962   ]
#  [ 2.2708068 ]
#  [ 2.0960107 ]
#  [ 1.8417937 ]
#  [ 1.5866739 ]
#  [ 1.3350017 ]
#  [ 1.1144905 ]
#  [ 0.8736297 ]
#  [ 0.68744653]
#  [ 0.5111903 ]
#  [ 0.33097157]
#  [ 0.13824162]
#  [ 0.00635797]
#  [-0.16559178]
#  [-0.24353057]
#  [-0.2910293 ]
#  [-0.28121337]
#  [-0.23772949]
#  [-0.16566566]
#  [-0.07052782]
#  [ 0.05706844]
#  [ 0.2888581 ]
#  [ 0.649634  ]
#  [ 1.0900567 ]
#  [ 1.5726758 ]
#  [ 1.8410249 ]
#  [ 2.0923786 ]
#  [ 2.2128177 ]
#  [ 2.3400712 ]
#  [ 2.4119797 ]
#  [ 2.4494724 ]
#  [ 2.4652047 ]
#  [ 2.4627962 ]
#  [ 2.4794235 ]
#  [ 2.4794698 ]
#  [ 2.5102553 ]
#  [ 2.4904466 ]
#  [ 2.4906445 ]
#  [ 2.4581804 ]
#  [ 2.4122558 ]
#  [ 2.3827038 ]
#  [ 2.3197436 ]
#  [ 2.2612047 ]
#  [ 2.2321105 ]
#  [ 2.2746549 ]
#  [ 2.4088316 ]
#  [ 2.4395757 ]
#  [ 2.5272584 ]
#  [ 2.5418859 ]
#  [ 2.4641218 ]
#  [ 2.3110204 ]
#  [ 2.1289444 ]
#  [ 1.8979442 ]
#  [ 1.6448159 ]
#  [ 1.4341213 ]
#  [ 1.1947814 ]
#  [ 1.021738  ]
#  [ 0.7675724 ]
#  [ 0.5914346 ]
#  [ 0.34911615]
#  [ 0.20799507]
#  [ 0.04918498]
#  [-0.0742676 ]
#  [-0.14714217]
#  [-0.1564652 ]
#  [-0.09919617]
#  [ 0.02718154]
#  [ 0.14718801]
#  [ 0.35244077]
#  [ 0.59634984]
#  [ 0.98296124]
#  [ 1.2924218 ]
#  [ 1.714388  ]
#  [ 1.8907168 ]
#  [ 2.0747986 ]
#  [ 2.1782541 ]
#  [ 2.2520437 ]
#  [ 2.2942553 ]
#  [ 2.331952  ]
#  [ 2.3459096 ]
#  [ 2.376192  ]
#  [ 2.3936744 ]
#  [ 2.3986611 ]
#  [ 2.3971558 ]
#  [ 2.345594  ]
#  [ 2.2226791 ]
#  [ 2.0821505 ]
#  [ 1.9298178 ]
#  [ 1.8391435 ]
#  [ 1.7718827 ]
#  [ 1.7642342 ]
#  [ 1.7918407 ]
#  [ 1.927509  ]
#  [ 2.0744634 ]
#  [ 2.1326416 ]
#  [ 2.1980677 ]
#  [ 2.1743355 ]
#  [ 2.1362047 ]
#  [ 2.0038471 ]
#  [ 1.7676367 ]
#  [ 1.537704  ]
#  [ 1.2814585 ]
#  [ 1.0930474 ]]

# %%
#3. Invers to original data
inv_data = scaler.inverse_transform(y_pred)
inv_data
# Out:
# array([[763.83545],
#        [744.09503],
#        [729.33496],
#        [711.4581 ],
#        [696.7934 ],
#        [681.2603 ],
#        [669.0503 ],
#        [658.69824],
#        [653.1397 ],
#        [649.36743],
#        [652.4689 ],
#        [662.23114],
#        [670.64685],
#        [680.713  ],
#        [695.0933 ],
#        [725.3381 ],
#        [755.1981 ],
#        [785.6917 ],
#        [817.281  ],
#        [837.10394],
#        [854.1739 ],
#        [862.6179 ],
#        [868.3221 ],
#        [873.34454],
#        [875.8701 ],
#        [878.1941 ],
#        [878.00256],
#        [882.09106],
#        [882.84485],
#        [885.5375 ],
#        [884.61395],
#        [881.3556 ],
#        [877.96014],
#        [872.71466],
#        [866.9502 ],
#        [862.0279 ],
#        [861.14545],
#        [875.438  ],
#        [888.5849 ],
#        [892.71576],
#        [899.2164 ],
#        [902.99536],
#        [901.7916 ],
#        [889.6831 ],
#        [871.6567 ],
#        [842.9506 ],
#        [820.6257 ],
#        [796.0315 ],
#        [771.90594],
#        [749.53424],
#        [724.27563],
#        [706.53326],
#        [685.4527 ],
#        [673.5049 ],
#        [660.2916 ],
#        [652.99896],
#        [647.4636 ],
#        [648.1707 ],
#        [650.4081 ],
#        [660.8934 ],
#        [668.36816],
#        [685.5418 ],
#        [705.1864 ],
#        [743.2849 ],
#        [781.7822 ],
#        [825.74426],
#        [850.0251 ],
#        [870.4015 ],
#        [882.6212 ],
#        [893.44666],
#        [902.24475],
#        [905.71796],
#        [908.4422 ],
#        [906.03735],
#        [907.40063],
#        [907.78674],
#        [906.94244],
#        [904.4202 ],
#        [902.06213],
#        [899.7369 ],
#        [896.1081 ],
#        [890.5411 ],
#        [881.15173],
#        [876.185  ],
#        [876.08215],
#        [883.75073],
#        [897.70636],
#        [903.7657 ],
#        [912.56244],
#        [910.28107],
#        [901.74664],
#        [889.4844 ],
#        [866.7469 ],
#        [848.0764 ],
#        [823.73663],
#        [804.8728 ],
#        [782.133  ],
#        [764.4374 ],
#        [748.534  ],
#        [728.19135],
#        [712.82166],
#        [695.6292 ],
#        [679.4207 ],
#        [672.4931 ],
#        [661.84204],
#        [664.14465],
#        [665.5772 ],
#        [676.6583 ],
#        [683.5982 ],
#        [699.2201 ],
#        [716.5272 ],
#        [750.15436],
#        [786.5807 ],
#        [824.5012 ],
#        [849.6258 ],
#        [868.6456 ],
#        [882.49854],
#        [890.9561 ],
#        [896.7981 ],
#        [899.2289 ],
#        [901.0978 ],
#        [900.89734],
#        [897.7341 ],
#        [894.48517],
#        [892.47205],
#        [882.00037],
#        [876.0296 ],
#        [861.9586 ],
#        [853.6802 ],
#        [842.84467],
#        [837.1871 ],
#        [832.0991 ],
#        [833.378  ],
#        [844.4436 ],
#        [868.64966],
#        [876.5901 ],
#        [885.1861 ],
#        [888.1733 ],
#        [885.7942 ],
#        [877.3148 ],
#        [858.4632 ],
#        [836.6206 ],
#        [811.4482 ],
#        [786.2608 ],
#        [762.53094],
#        [737.5528 ],
#        [707.16504],
#        [690.91986],
#        [666.899  ],
#        [657.32654],
#        [644.8921 ],
#        [642.2754 ],
#        [638.29724],
#        [641.3744 ],
#        [644.9663 ],
#        [655.33356],
#        [668.0241 ],
#        [683.581  ],
#        [701.561  ],
#        [728.78595],
#        [758.7949 ],
#        [796.12604],
#        [822.13715],
#        [844.12646],
#        [859.14856],
#        [869.82294],
#        [873.6332 ],
#        [879.2283 ],
#        [878.79895],
#        [877.81696],
#        [877.3782 ],
#        [877.14435],
#        [874.4705 ],
#        [871.304  ],
#        [860.70734],
#        [849.31573],
#        [839.3637 ],
#        [830.7628 ],
#        [827.2678 ],
#        [825.0674 ],
#        [835.0523 ],
#        [855.6835 ],
#        [888.68835],
#        [896.3403 ],
#        [895.5763 ],
#        [886.4621 ],
#        [870.65027],
#        [851.7614 ],
#        [828.46356],
#        [810.28424],
#        [788.31445],
#        [765.13934],
#        [740.312  ],
#        [720.01483],
#        [696.9292 ],
#        [680.64886],
#        [661.66174],
#        [647.8158 ],
#        [635.5991 ],
#        [630.28314],
#        [625.6906 ],
#        [629.21735],
#        [633.2585 ],
#        [642.6411 ],
#        [651.9388 ],
#        [666.6018 ],
#        [684.91766],
#        [712.22784],
#        [746.1623 ],
#        [780.6316 ],
#        [811.4177 ],
#        [828.2251 ],
#        [845.08636],
#        [853.0568 ],
#        [857.4367 ],
#        [863.253  ],
#        [863.92413],
#        [862.5868 ],
#        [860.15564],
#        [858.3182 ],
#        [854.64154],
#        [848.16907],
#        [841.83575],
#        [830.4822 ],
#        [826.23694],
#        [818.34766],
#        [815.667  ],
#        [815.5109 ],
#        [823.4156 ],
#        [844.8374 ],
#        [876.8244 ],
#        [893.79224],
#        [904.47485],
#        [901.28845],
#        [888.47784],
#        [871.0943 ],
#        [845.81226],
#        [820.4405 ],
#        [795.41156],
#        [773.48157],
#        [749.52783],
#        [731.01184],
#        [713.48303],
#        [695.5602 ],
#        [676.39307],
#        [663.27716],
#        [646.1767 ],
#        [638.4256 ],
#        [633.70184],
#        [634.67804],
#        [639.00256],
#        [646.1693 ],
#        [655.63086],
#        [668.3204 ],
#        [691.37195],
#        [727.25134],
#        [771.05164],
#        [819.04834],
#        [845.73584],
#        [870.7331 ],
#        [882.7108 ],
#        [895.3663 ],
#        [902.5176 ],
#        [906.2463 ],
#        [907.81085],
#        [907.57135],
#        [909.2249 ],
#        [909.22955],
#        [912.29114],
#        [910.32117],
#        [910.3409 ],
#        [907.1123 ],
#        [902.54504],
#        [899.6061 ],
#        [893.34467],
#        [887.52295],
#        [884.6295 ],
#        [888.8606 ],
#        [902.2045 ],
#        [905.262  ],
#        [913.9821 ],
#        [915.4368 ],
#        [907.7032 ],
#        [892.4771 ],
#        [874.36957],
#        [851.3965 ],
#        [826.2227 ],
#        [805.26904],
#        [781.46655],
#        [764.25726],
#        [738.98035],
#        [721.4634 ],
#        [697.3647 ],
#        [683.3301 ],
#        [667.5363 ],
#        [655.2589 ],
#        [648.0115 ],
#        [647.0843 ],
#        [652.7798 ],
#        [665.3481 ],
#        [677.2828 ],
#        [697.6953 ],
#        [721.9522 ],
#        [760.40094],
#        [791.17694],
#        [833.1417 ],
#        [850.67773],
#        [868.98474],
#        [879.27344],
#        [886.6119 ],
#        [890.8098 ],
#        [894.55884],
#        [895.9469 ],
#        [898.9585 ],
#        [900.69714],
#        [901.19305],
#        [901.04333],
#        [895.91547],
#        [883.6915 ],
#        [869.7159 ],
#        [854.56635],
#        [845.5487 ],
#        [838.8596 ],
#        [838.09894],
#        [840.8444 ],
#        [854.33673],
#        [868.9514 ],
#        [874.73724],
#        [881.2439 ],
#        [878.8837 ],
#        [875.0916 ],
#        [861.9286 ],
#        [838.4373 ],
#        [815.5704 ],
#        [790.0866 ],
#        [771.34906]], dtype=float32)

# %%
#4. Copy Dataframe
viz = df.copy()
viz
# Out:
#                  datetime    load
# 0     2018-01-01 00:30:00  554.80
# 1     2018-01-01 01:00:00  545.80
# 2     2018-01-01 01:30:00  534.70
# 3     2018-01-01 02:00:00  521.50
# 4     2018-01-01 02:30:00  496.50
# ...                   ...     ...
# 35035 2019-12-31 22:00:00  807.81
# 35036 2019-12-31 22:30:00  788.11
# 35037 2019-12-31 23:00:00  773.05
# 35038 2019-12-31 23:30:00  753.55
# 35039 2020-01-01 00:00:00  726.00
#
# [35040 rows x 2 columns]

# %%
#5. Generate new forecasting date
from prophet import Prophet
m = Prophet()

viz = viz.rename(columns={'datetime': 'ds', 'load' : 'y'})

m.fit(viz)
future = m.make_future_dataframe(periods=n_steps, freq='30 min', include_history=False)
future
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpi4y841s9/76m69bnm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpi4y841s9/1zb72utp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81649', 'data', 'file=/tmp/tmpi4y841s9/76m69bnm.json', 'init=/tmp/tmpi4y841s9/1zb72utp.json', 'output', 'file=/tmp/tmpi4y841s9/prophet_model_hwhxxtr/prophet_model-20230413055350.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:53:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:54:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#                      ds
# 0   2020-01-01 00:30:00
# 1   2020-01-01 01:00:00
# 2   2020-01-01 01:30:00
# 3   2020-01-01 02:00:00
# 4   2020-01-01 02:30:00
# ..                  ...
# 331 2020-01-07 22:00:00
# 332 2020-01-07 22:30:00
# 333 2020-01-07 23:00:00
# 334 2020-01-07 23:30:00
# 335 2020-01-08 00:00:00
#
# [336 rows x 1 columns]

# %%
#6. Merge Forecasting Date and Data
future['load'] = inv_data
future = future.rename(columns={'ds': 'datetime'})
future
# Out:
#                datetime        load
# 0   2020-01-01 00:30:00  763.835449
# 1   2020-01-01 01:00:00  744.095032
# 2   2020-01-01 01:30:00  729.334961
# 3   2020-01-01 02:00:00  711.458130
# 4   2020-01-01 02:30:00  696.793396
# ..                  ...         ...
# 331 2020-01-07 22:00:00  861.928589
# 332 2020-01-07 22:30:00  838.437317
# 333 2020-01-07 23:00:00  815.570374
# 334 2020-01-07 23:30:00  790.086609
# 335 2020-01-08 00:00:00  771.349060
#
# [336 rows x 2 columns]

# %%
#7. Copy historical data for Visualization
history_predict = n_steps #Set by window_size, 48 = 1 Day

hist_data = df.copy()
hist_data

start_index = len(hist_data) - history_predict
hist_data = hist_data[start_index:]

# %%
len(hist_data)
# Out:
# 48

# %%
hist_data.tail(50)
# Out:
#                  datetime    load
# 34990 2019-12-30 23:30:00  807.07
# 34991 2019-12-31 00:00:00  785.41
# 34992 2019-12-31 00:30:00  752.90
# 34993 2019-12-31 01:00:00  735.00
# 34994 2019-12-31 01:30:00  718.11
# 34995 2019-12-31 02:00:00  706.46
# 34996 2019-12-31 02:30:00  692.98
# 34997 2019-12-31 03:00:00  677.04
# 34998 2019-12-31 03:30:00  669.84
# 34999 2019-12-31 04:00:00  664.78
# 35000 2019-12-31 04:30:00  665.44
# 35001 2019-12-31 05:00:00  668.89
# 35002 2019-12-31 05:30:00  680.42
# 35003 2019-12-31 06:00:00  683.71
# 35004 2019-12-31 06:30:00  689.92
# 35005 2019-12-31 07:00:00  707.35
# 35006 2019-12-31 07:30:00  745.47
# 35007 2019-12-31 08:00:00  781.94
# 35008 2019-12-31 08:30:00  838.62
# 35009 2019-12-31 09:00:00  867.38
# 35010 2019-12-31 09:30:00  894.29
# 35011 2019-12-31 10:00:00  907.99
# 35012 2019-12-31 10:30:00  908.29
# 35013 2019-12-31 11:00:00  909.06
# 35014 2019-12-31 11:30:00  913.76
# 35015 2019-12-31 12:00:00  906.82
# 35016 2019-12-31 12:30:00  915.29
# 35017 2019-12-31 13:00:00  910.85
# 35018 2019-12-31 13:30:00  913.64
# 35019 2019-12-31 14:00:00  899.18
# 35020 2019-12-31 14:30:00  871.83
# 35021 2019-12-31 15:00:00  848.17
# 35022 2019-12-31 15:30:00  830.34
# 35023 2019-12-31 16:00:00  826.54
# 35024 2019-12-31 16:30:00  825.26
# 35025 2019-12-31 17:00:00  825.29
# 35026 2019-12-31 17:30:00  818.92
# 35027 2019-12-31 18:00:00  827.47
# 35028 2019-12-31 18:30:00  858.42
# 35029 2019-12-31 19:00:00  897.37
# 35030 2019-12-31 19:30:00  894.51
# 35031 2019-12-31 20:00:00  881.38
# 35032 2019-12-31 20:30:00  865.26
# 35033 2019-12-31 21:00:00  850.45
# 35034 2019-12-31 21:30:00  831.64
# 35035 2019-12-31 22:00:00  807.81
# 35036 2019-12-31 22:30:00  788.11
# 35037 2019-12-31 23:00:00  773.05
# 35038 2019-12-31 23:30:00  753.55
# 35039 2020-01-01 00:00:00  726.00

# %%
#8. Set Index
hist_data = hist_data.set_index('datetime')
future_data = future.set_index('datetime')

# %%
future_data
# Out:
#                            load
# datetime
# 2020-01-01 00:30:00  763.835449
# 2020-01-01 01:00:00  744.095032
# 2020-01-01 01:30:00  729.334961
# 2020-01-01 02:00:00  711.458130
# 2020-01-01 02:30:00  696.793396
# ...                         ...
# 2020-01-07 22:00:00  861.928589
# 2020-01-07 22:30:00  838.437317
# 2020-01-07 23:00:00  815.570374
# 2020-01-07 23:30:00  790.086609
# 2020-01-08 00:00:00  771.349060
#
# [336 rows x 1 columns]

# %%
#9. Visualization

import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15, 5))
hist_data.plot(ax=ax, label='Training Data', title='Observed Data')
future_data.plot(ax=ax, label='Predicted')
ax.axvline('2020-01-01', color='black', ls='--')
ax.legend(['Training Set', 'Predicted'])
plt.show()
